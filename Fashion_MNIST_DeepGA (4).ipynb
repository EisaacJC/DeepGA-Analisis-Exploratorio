# %% [markdown]
# # **Dataset:** *Fashion-MNIST*
# # **Generaciones:** *20 generaciones*
# # **Porcentaje de cruza:** *70 %*
# # **Porcentaje de mutación:** *70 %*
# Ejecutado en Google Colaboratory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Información del sistema de ejecución

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Fri Jun 24 08:23:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4827677942847244615
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3988879150760644398
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %% [markdown]
# ## Lectura de datos

# %%
# !cp /content/drive/MyDrive/DGA_fashion/DataReader.py /content
# !cp /content/drive/MyDrive/DGA_fashion/Decoding.py /content
# !cp /content/drive/MyDrive/DGA_fashion/DistributedTraining.py /content
# !cp /content/drive/MyDrive/DGA_fashion/EncodingClass.py /content
# !cp /content/drive/MyDrive/DGA_fashion/Operators.py /content
# Ruta del dataset
# !cp /content/drive/MyDrive/Datasets/fashion.zip /content

# %%
# Descomprimir dataset
# !unzip fashion.zip

# %% [markdown]
# # Ejecución 1

# %%
## MÓDULOS ##########################################################################################
from Operators import *
from EncodingClass import *
from Decoding import *
from DataReader import *
from DistributedTraining import *

## LIBRERÍAS ########################################################################################
import numpy as np
from torch import optim
import pandas as pd
import timeit
import torch
from torch import nn
import pickle

## HIPERPARÁMETROS DE LA CNN ########################################################################
loss_func = nn.NLLLoss(reduction = "sum") #Defining loss function
lr = 1e-4 #Defining learning rate
#Maximun and minimum numbers of layers to initialize networks
min_conv = 2
max_conv = 5
min_full = 1
max_full = 4
w = 0.3 #penalization weight
max_params = 2e6
num_epochs = 10

## PARÁMETROS GA ####################################################################################
N = 20 #Population size
cr = 0.7 #Crossover rate
mr = 0.7 #Mutation rate
#T = 50 #Number of generations
t_size = 5 #tournament size
train_dl, test_dl = loading_data()
#device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device1 = torch.device("cuda:0")
device1 = torch.device("cuda")

## CREAR POBLACIÓN ##################################################################################
pop = []
bestAcc = []
bestF = []
bestParams = []
print("Iniciando población...\n")
while len(pop) < N:
  while True:
    try:
      acc_list = []
      #Creating genomes (genetic encoding)
      e1 = Encoding(min_conv,max_conv,min_full,max_full)
      #Decoding the network
      network1 = decoding(e1)
      #Creating the CNN
      cnn1 = CNN(e1, network1[0], network1[1], network1[2])
      print("Individuo {} creado:".format(len(pop)+1))
      #Training the CNN
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc_list)
      #Add individual to population
      pop.append([e1,acc_list[0][1],acc_list[0][2],acc_list[0][3]])
      print("Individuo {} evaluado.\n".format(len(pop)))
      break
    except:
      pass

print("Población creada!!")
# Out:
# Iniciando población...
#
# Individuo 1 creado:
# Individuo 1 evaluado.
#
# Individuo 2 creado:
# Individuo 2 evaluado.
#
# Individuo 3 creado:
# Individuo 3 evaluado.
#
# Individuo 4 creado:
# Individuo 4 evaluado.
#
# Individuo 5 creado:
# Individuo 5 evaluado.
#
# Individuo 6 creado:
# Individuo 6 evaluado.
#
# Individuo 7 creado:
# Individuo 7 evaluado.
#
# Individuo 8 creado:
# Individuo 8 evaluado.
#
# Individuo 9 creado:
# Individuo 9 evaluado.
#
# Individuo 10 creado:
# Individuo 10 evaluado.
#
# Individuo 11 creado:
# Individuo 11 evaluado.
#
# Individuo 12 creado:
# Individuo 12 evaluado.
#
# Individuo 13 creado:
# Individuo 13 evaluado.
#
# Individuo 14 creado:
# Individuo 14 evaluado.
#
# Individuo 15 creado:
# Individuo 15 evaluado.
#
# Individuo 16 creado:
# Individuo 16 evaluado.
#
# Individuo 17 creado:
# Individuo 17 creado:
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Individuo 17 evaluado.
#
# Individuo 18 creado:
# Individuo 18 evaluado.
#
# Individuo 19 creado:
# Individuo 19 evaluado.
#
# Individuo 20 creado:
# Individuo 20 creado:
# Individuo 20 evaluado.
#
# Población creada!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población inicial
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.8408758, acc:0.7887142857142857, param:74828
# f:0.8169305333333332, acc:0.7396190476190476, param:5352
# f:0.9033706333333332, acc:0.8997619047619048, param:176418
# f:0.7945987999999999, acc:0.7078571428571429, param:6008
# f:0.8743268333333333, acc:0.8801904761904762, param:278710
# f:0.8911842666666665, acc:0.8538095238095238, param:43216
# f:0.6686585333333332, acc:0.5270476190476191, param:1832
# f:0.8916379333333333, acc:0.8521904761904762, param:32636
# f:0.8529969333333333, acc:0.7924761904761904, param:11576
# f:0.8806161333333333, acc:0.8331904761904761, param:17448
# f:0.8787474, acc:0.8301428571428572, param:15684
# f:0.8857538666666667, acc:0.8395238095238096, param:12752
# f:0.8681836999999999, acc:0.8158571428571428, param:19442
# f:0.7552074, acc:0.6638571428571428, param:63284
# f:0.7108979, acc:0.5887142857142857, param:8014
# f:0.8475141333333331, acc:0.7834761904761904, param:6128
# f:0.8302265666666666, acc:0.7585238095238095, param:4934
# f:0.8548434999999999, acc:0.7955714285714286, param:13710
# f:0.8086597333333332, acc:0.7279047619047619, param:5824
# f:0.8702847666666667, acc:0.8156666666666667, param:4546
# [<EncodingClass.Encoding at 0x7fe2ea5afc50>,
#  0.9033706333333332,
#  0.8997619047619048,
#  176418]

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)
    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 aleatorio de pop.
# Descendiente 7 evaluado.
# Descendiente 8 aleatorio de pop.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9118804333333332
# Best accuracy:  0.8830476190476191
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9118804333333332
# Best accuracy:  0.8830476190476191
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 aleatorio de pop.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  3
# Descendiente 1 aleatorio de pop.
# Descendiente 2 evaluado.
# Descendiente 3 aleatorio de pop.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 aleatorio de pop.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 aleatorio de pop.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 aleatorio de pop.
# Descendiente 4 aleatorio de pop.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  7
# Descendiente 1 aleatorio de pop.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  8
# Descendiente 1 aleatorio de pop.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 aleatorio de pop.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9151398333333334
# Best accuracy:  0.8901904761904762
# Best No. of Params:  53290
# No. of Conv. Layers:  4
# No. of FC Layers:  3
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9170185
# Best accuracy:  0.8847142857142857
# Best No. of Params:  15210
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9190297
# Best accuracy:  0.9065714285714286
# Best No. of Params:  103802
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9190297
# Best accuracy:  0.9065714285714286
# Best No. of Params:  103802
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9207787666666665
# Best accuracy:  0.9070952380952381
# Best No. of Params:  94586
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9207787666666665
# Best accuracy:  0.9070952380952381
# Best No. of Params:  94586
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9214198333333333
# Best accuracy:  0.9126190476190477
# Best No. of Params:  116090
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9246298333333332
# Best accuracy:  0.9044761904761904
# Best No. of Params:  56690
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9246298333333332
# Best accuracy:  0.9044761904761904
# Best No. of Params:  56690
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9246298333333332
# Best accuracy:  0.9044761904761904
# Best No. of Params:  56690
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9246298333333332
# Best accuracy:  0.9044761904761904
# Best No. of Params:  56690
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9246298333333332
# Best accuracy:  0.9044761904761904
# Best No. of Params:  56690
# No. of Conv. Layers:  2
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población final
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.9246298333333332, acc:0.9044761904761904, param:56690
# f:0.9234910333333333, acc:0.9057619047619048, param:70282
# f:0.9234663666666665, acc:0.8970952380952381, param:30002
# f:0.9228140999999999, acc:0.9038571428571428, param:65906
# f:0.9221296999999999, acc:0.911, param:103802
# f:0.9218895666666667, acc:0.8983809523809524, param:46514
# f:0.9216787666666666, acc:0.9083809523809524, param:94586
# f:0.9215228999999999, acc:0.8978571428571429, param:46514
# f:0.9214562333333333, acc:0.8977619047619048, param:46514
# f:0.9214228999999999, acc:0.8977142857142857, param:46514
# f:0.9214198333333333, acc:0.9126190476190477, param:116090
# f:0.9208768999999999, acc:0.9161428571428571, param:136154
# f:0.9207787666666665, acc:0.9070952380952381, param:94586
# f:0.9205298333333334, acc:0.8986190476190477, param:56690
# f:0.9204630333333333, acc:0.9086190476190477, param:103802
# f:0.9204412999999999, acc:0.8921428571428571, param:27058
# f:0.9203486333333333, acc:0.9016190476190477, param:71898
# f:0.9202787666666665, acc:0.9063809523809524, param:94586
# f:0.9201120999999999, acc:0.9061428571428571, param:94586
# f:0.9197746333333333, acc:0.8911904761904762, param:27058
# [<EncodingClass.Encoding at 0x7fe2e786b790>,
#  0.9246298333333332,
#  0.9044761904761904,
#  56690]

# %% [markdown]
# # Ejecución 2

# %%
## MÓDULOS ##########################################################################################
from Operators import *
from EncodingClass import *
from Decoding import *
from DataReader import *
from DistributedTraining import *

## LIBRERÍAS ########################################################################################
import numpy as np
from torch import optim
import pandas as pd
import timeit
import torch
from torch import nn
import pickle

## HIPERPARÁMETROS DE LA CNN ########################################################################
loss_func = nn.NLLLoss(reduction = "sum") #Defining loss function
lr = 1e-4 #Defining learning rate
#Maximun and minimum numbers of layers to initialize networks
min_conv = 2
max_conv = 5
min_full = 1
max_full = 4
w = 0.3 #penalization weight
max_params = 2e6
num_epochs = 10

## PARÁMETROS GA ####################################################################################
N = 20 #Population size
cr = 0.7 #Crossover rate
mr = 0.7 #Mutation rate
#T = 50 #Number of generations
t_size = 5 #tournament size
train_dl, test_dl = loading_data()
#device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device1 = torch.device("cuda:0")
device1 = torch.device("cuda")

## CREAR POBLACIÓN ##################################################################################
pop = []
bestAcc = []
bestF = []
bestParams = []
print("Iniciando población...\n")
while len(pop) < N:
  while True:
    try:
      acc_list = []
      #Creating genomes (genetic encoding)
      e1 = Encoding(min_conv,max_conv,min_full,max_full)
      #Decoding the network
      network1 = decoding(e1)
      #Creating the CNN
      cnn1 = CNN(e1, network1[0], network1[1], network1[2])
      print("Individuo {} creado:".format(len(pop)+1))
      #Training the CNN
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc_list)
      #Add individual to population
      pop.append([e1,acc_list[0][1],acc_list[0][2],acc_list[0][3]])
      print("Individuo {} evaluado.\n".format(len(pop)))
      break
    except:
      pass

print("Población creada!!")
# Out:
# Iniciando población...
#
# Individuo 1 creado:
# Individuo 1 evaluado.
#
# Individuo 2 creado:
# Individuo 2 evaluado.
#
# Individuo 3 creado:
# Individuo 3 evaluado.
#
# Individuo 4 creado:
# Individuo 4 evaluado.
#
# Individuo 5 creado:
# Individuo 5 evaluado.
#
# Individuo 6 creado:
# Individuo 6 evaluado.
#
# Individuo 7 creado:
# Individuo 7 evaluado.
#
# Individuo 8 creado:
# Individuo 8 evaluado.
#
# Individuo 9 creado:
# Individuo 9 evaluado.
#
# Individuo 10 creado:
# Individuo 10 evaluado.
#
# Individuo 11 creado:
# Individuo 11 evaluado.
#
# Individuo 12 creado:
# Individuo 12 evaluado.
#
# Individuo 13 creado:
# Individuo 13 evaluado.
#
# Individuo 14 creado:
# Individuo 14 evaluado.
#
# Individuo 15 creado:
# Individuo 15 evaluado.
#
# Individuo 16 creado:
# Individuo 16 evaluado.
#
# Individuo 17 creado:
# Individuo 17 evaluado.
#
# Individuo 18 creado:
# Individuo 18 evaluado.
#
# Individuo 19 creado:
# Individuo 19 evaluado.
#
# Individuo 20 creado:
# Individuo 20 evaluado.
#
# Población creada!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población inicial
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.7972474666666666, acc:0.8590952380952381, param:694128
# f:0.9060834333333333, acc:0.8756190476190476, param:45666
# f:0.6256759333333333, acc:0.46776190476190477, param:11716
# f:0.8848904999999999, acc:0.8378571428571429, param:10730
# f:0.8300363333333333, acc:0.7593333333333333, param:9980
# f:0.8031521, acc:0.7198571428571429, param:4986
# f:0.7941704666666667, acc:0.7173809523809523, param:53308
# f:0.8892834666666667, acc:0.8443809523809523, param:11888
# f:0.8406063666666665, acc:0.7800952380952381, param:36402
# f:0.8923125333333333, acc:0.8499047619047619, param:17472
# f:0.8405416666666665, acc:0.772952380952381, param:3500
# f:0.7613673666666666, acc:0.6750952380952381, param:74662
# f:0.8864485333333333, acc:0.8457619047619047, param:37232
# f:0.8563753666666667, acc:0.8025238095238095, param:35942
# f:0.8884643666666665, acc:0.9016666666666666, param:284682
# f:0.8925166333333332, acc:0.8560476190476191, param:44778
# f:0.8887667666666665, acc:0.8433809523809523, param:10666
# f:0.9074472333333332, acc:0.8713333333333333, param:16574
# f:0.8865850999999999, acc:0.848, param:46766
# f:0.7540828666666667, acc:0.6542380952380953, param:25892
# [<EncodingClass.Encoding at 0x7fe2e6f673d0>,
#  0.9074472333333332,
#  0.8713333333333333,
#  16574]

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9074472333333332
# Best accuracy:  0.8713333333333333
# Best No. of Params:  16574
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9074472333333332
# Best accuracy:  0.8713333333333333
# Best No. of Params:  16574
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9074472333333332
# Best accuracy:  0.8713333333333333
# Best No. of Params:  16574
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197468999999998
# Best accuracy:  0.8957142857142857
# Best No. of Params:  48354
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9212675666666668
# Best accuracy:  0.9068095238095238
# Best No. of Params:  89994
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9212675666666668
# Best accuracy:  0.9068095238095238
# Best No. of Params:  89994
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 aleatorio de pop.
# Descendiente 8 aleatorio de pop.
# Descendiente 9 evaluado.
# Descendiente 10 aleatorio de pop.
# Best fitness:  0.9212675666666668
# Best accuracy:  0.9068095238095238
# Best No. of Params:  89994
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 aleatorio de pop.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9245557
# Best accuracy:  0.9035714285714286
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 aleatorio de pop.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9266706333333332
# Best accuracy:  0.9064761904761904
# Best No. of Params:  52418
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9266706333333332
# Best accuracy:  0.9064761904761904
# Best No. of Params:  52418
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 10 evaluado.
# Best fitness:  0.9266706333333332
# Best accuracy:  0.9064761904761904
# Best No. of Params:  52418
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9266706333333332
# Best accuracy:  0.9064761904761904
# Best No. of Params:  52418
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 aleatorio de pop.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9266706333333332
# Best accuracy:  0.9064761904761904
# Best No. of Params:  52418
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9278890333333332
# Best accuracy:  0.9083333333333333
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9278890333333332
# Best accuracy:  0.9083333333333333
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9278890333333332
# Best accuracy:  0.9083333333333333
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9289223666666666
# Best accuracy:  0.9098095238095238
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 aleatorio de pop.
# Descendiente 8 evaluado.
# Descendiente 9 aleatorio de pop.
# Descendiente 10 evaluado.
# Best fitness:  0.9289223666666666
# Best accuracy:  0.9098095238095238
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9289223666666666
# Best accuracy:  0.9098095238095238
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 aleatorio de pop.
# Descendiente 10 evaluado.
# Best fitness:  0.9289223666666666
# Best accuracy:  0.9098095238095238
# Best No. of Params:  52962
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población final
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.9289223666666666, acc:0.9098095238095238, param:52962
# f:0.9278890333333332, acc:0.9083333333333333, param:52962
# f:0.9278625, acc:0.909, param:56250
# f:0.9278625, acc:0.909, param:56250
# f:0.9278223666666667, acc:0.9082380952380953, param:52962
# f:0.9266706333333332, acc:0.9064761904761904, param:52418
# f:0.9245557, acc:0.9035714285714286, param:52962
# f:0.9244741, acc:0.8975714285714286, param:25506
# f:0.9241162333333333, acc:0.9164761904761904, param:116114
# f:0.9234815666666665, acc:0.9016666666666666, param:51234
# f:0.9233802333333332, acc:0.9009047619047619, param:48354
# f:0.9232706333333334, acc:0.9016190476190477, param:52418
# f:0.9232706333333334, acc:0.9016190476190477, param:52418
# f:0.9231135666666666, acc:0.9005238095238095, param:48354
# f:0.9231135666666666, acc:0.9005238095238095, param:48354
# f:0.9230467, acc:0.9022857142857142, param:57022
# f:0.9226468999999999, acc:0.8998571428571429, param:48354
# f:0.9219921, acc:0.9107142857142857, param:103386
# f:0.9214426333333332, acc:0.8984761904761904, param:49938
# f:0.9213901, acc:0.907, param:90066
# [<EncodingClass.Encoding at 0x7fe2e6df8310>,
#  0.9289223666666666,
#  0.9098095238095238,
#  52962]

# %% [markdown]
# # Ejecución 3

# %%
## MÓDULOS ##########################################################################################
from Operators import *
from EncodingClass import *
from Decoding import *
from DataReader import *
from DistributedTraining import *

## LIBRERÍAS ########################################################################################
import numpy as np
from torch import optim
import pandas as pd
import timeit
import torch
from torch import nn
import pickle

## HIPERPARÁMETROS DE LA CNN ########################################################################
loss_func = nn.NLLLoss(reduction = "sum") #Defining loss function
lr = 1e-4 #Defining learning rate
#Maximun and minimum numbers of layers to initialize networks
min_conv = 2
max_conv = 5
min_full = 1
max_full = 4
w = 0.3 #penalization weight
max_params = 2e6
num_epochs = 10

## PARÁMETROS GA ####################################################################################
N = 20 #Population size
cr = 0.7 #Crossover rate
mr = 0.7 #Mutation rate
#T = 50 #Number of generations
t_size = 5 #tournament size
train_dl, test_dl = loading_data()
#device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device1 = torch.device("cuda:0")
device1 = torch.device("cuda")

## CREAR POBLACIÓN ##################################################################################
pop = []
bestAcc = []
bestF = []
bestParams = []
print("Iniciando población...\n")
while len(pop) < N:
  while True:
    try:
      acc_list = []
      #Creating genomes (genetic encoding)
      e1 = Encoding(min_conv,max_conv,min_full,max_full)
      #Decoding the network
      network1 = decoding(e1)
      #Creating the CNN
      cnn1 = CNN(e1, network1[0], network1[1], network1[2])
      print("Individuo {} creado:".format(len(pop)+1))
      #Training the CNN
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc_list)
      #Add individual to population
      pop.append([e1,acc_list[0][1],acc_list[0][2],acc_list[0][3]])
      print("Individuo {} evaluado.\n".format(len(pop)))
      break
    except:
      pass

print("Población creada!!")
# Out:
# Iniciando población...
#
# Individuo 1 creado:
# Individuo 1 evaluado.
#
# Individuo 2 creado:
# Individuo 2 evaluado.
#
# Individuo 3 creado:
# Individuo 3 evaluado.
#
# Individuo 4 creado:
# Individuo 4 evaluado.
#
# Individuo 5 creado:
# Individuo 5 evaluado.
#
# Individuo 6 creado:
# Individuo 6 evaluado.
#
# Individuo 7 creado:
# Individuo 7 evaluado.
#
# Individuo 8 creado:
# Individuo 8 evaluado.
#
# Individuo 9 creado:
# Individuo 9 evaluado.
#
# Individuo 10 creado:
# Individuo 10 evaluado.
#
# Individuo 11 creado:
# Individuo 11 evaluado.
#
# Individuo 12 creado:
# Individuo 12 evaluado.
#
# Individuo 13 creado:
# Individuo 13 evaluado.
#
# Individuo 14 creado:
# Individuo 14 evaluado.
#
# Individuo 15 creado:
# Individuo 15 evaluado.
#
# Individuo 16 creado:
# Individuo 16 evaluado.
#
# Individuo 17 creado:
# Individuo 17 creado:
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Individuo 17 evaluado.
#
# Individuo 18 creado:
# Individuo 18 evaluado.
#
# Individuo 19 creado:
# Individuo 19 evaluado.
#
# Individuo 20 creado:
# Individuo 20 creado:
# Individuo 20 evaluado.
#
# Población creada!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población inicial
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.6627424666666667, acc:0.5342380952380953, param:74828
# f:0.7737638666666666, acc:0.677952380952381, param:5352
# f:0.9030706333333333, acc:0.8993333333333333, param:176418
# f:0.7552987999999999, acc:0.6517142857142857, param:6008
# f:0.8697934999999999, acc:0.8737142857142857, param:278710
# f:0.8884842666666666, acc:0.8499523809523809, param:43216
# f:0.7132918666666666, acc:0.5908095238095238, param:1832
# f:0.8866712666666667, acc:0.8450952380952381, param:32636
# f:0.8301302666666666, acc:0.7598095238095238, param:11576
# f:0.8779494666666665, acc:0.8293809523809523, param:17448
# f:0.8563807333333333, acc:0.7981904761904762, param:15684
# f:0.8848538666666667, acc:0.8382380952380952, param:12752
# f:0.8575503666666666, acc:0.8006666666666666, param:19442
# f:0.8413074, acc:0.7868571428571428, param:63284
# f:0.7803645666666666, acc:0.687952380952381, param:8014
# f:0.8508474666666666, acc:0.7882380952380953, param:6128
# f:0.8435265666666665, acc:0.7775238095238095, param:4934
# f:0.8677101666666667, acc:0.813952380952381, param:13710
# f:0.8192264, acc:0.743, param:5824
# f:0.8517514333333334, acc:0.7891904761904762, param:4546
# [<EncodingClass.Encoding at 0x7f32a16930d0>,
#  0.9030706333333333,
#  0.8993333333333333,
#  176418]

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 aleatorio de pop.
# Descendiente 7 evaluado.
# Descendiente 8 aleatorio de pop.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9108137666666667
# Best accuracy:  0.8815238095238095
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 aleatorio de pop.
# Descendiente 3 evaluado.
# Descendiente 4 aleatorio de pop.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9108137666666667
# Best accuracy:  0.8815238095238095
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9180343
# Best accuracy:  0.892
# Best No. of Params:  42438
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9180343
# Best accuracy:  0.892
# Best No. of Params:  42438
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9180343
# Best accuracy:  0.892
# Best No. of Params:  42438
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9180343
# Best accuracy:  0.892
# Best No. of Params:  42438
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9180343
# Best accuracy:  0.892
# Best No. of Params:  42438
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9190209666666666
# Best accuracy:  0.894095238095238
# Best No. of Params:  45638
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Fin genético!!

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9197440333333333
# Best accuracy:  0.8946190476190476
# Best No. of Params:  43262
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9217553666666667
# Best accuracy:  0.899952380952381
# Best No. of Params:  54742
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9217553666666667
# Best accuracy:  0.899952380952381
# Best No. of Params:  54742
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9225743
# Best accuracy:  0.902
# Best No. of Params:  58838
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 aleatorio de pop.
# Best fitness:  0.9225743
# Best accuracy:  0.902
# Best No. of Params:  58838
# No. of Conv. Layers:  4
# No. of FC Layers:  1
# --------------------------------------------
# Fin genético!!
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")

# %%
 #Mostrar aptitudes, precisión y num. parámetros de población final
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.9225743, acc:0.902, param:58838
# f:0.9217553666666667, acc:0.899952380952381, param:54742
# f:0.9215647, acc:0.9005714285714286, param:58902
# f:0.9199820333333333, acc:0.8977619047619048, param:56342
# f:0.9197440333333333, acc:0.8946190476190476, param:43262
# f:0.9194869666666667, acc:0.9058095238095238, param:97198
# f:0.9194543, acc:0.8947142857142857, param:45638
# f:0.9192473666666665, acc:0.8939523809523809, param:43462
# f:0.9190542999999999, acc:0.8941428571428571, param:45638
# f:0.9190338999999998, acc:0.8937142857142857, param:43774
# f:0.9190209666666666, acc:0.894095238095238, param:45638
# f:0.9190209666666666, acc:0.894095238095238, param:45638
# f:0.9180343, acc:0.892, param:42438
# f:0.9177089666666667, acc:0.8965238095238095, param:65718
# f:0.9176127, acc:0.8922857142857142, param:46582
# f:0.9174529666666666, acc:0.898952380952381, param:78758
# f:0.9171101666666666, acc:0.8909523809523809, param:43710
# f:0.9171009666666666, acc:0.8906666666666667, param:42438
# f:0.9169869666666666, acc:0.9022380952380953, param:97198
# f:0.9169202999999999, acc:0.9021428571428571, param:97198
# [<EncodingClass.Encoding at 0x7f329e051210>, 0.9225743, 0.902, 58838]

# %% [markdown]
# # Ejecución 4

# %%
## MÓDULOS ##########################################################################################
from Operators import *
from EncodingClass import *
from Decoding import *
from DataReader import *
from DistributedTraining import *

## LIBRERÍAS ########################################################################################
import numpy as np
from torch import optim
import pandas as pd
import timeit
import torch
from torch import nn
import pickle

## HIPERPARÁMETROS DE LA CNN ########################################################################
loss_func = nn.NLLLoss(reduction = "sum") #Defining loss function
lr = 1e-4 #Defining learning rate
#Maximun and minimum numbers of layers to initialize networks
min_conv = 2
max_conv = 5
min_full = 1
max_full = 4
w = 0.3 #penalization weight
max_params = 2e6
num_epochs = 10

## PARÁMETROS GA ####################################################################################
N = 20 #Population size
cr = 0.7 #Crossover rate
mr = 0.7 #Mutation rate
#T = 50 #Number of generations
t_size = 5 #tournament size
train_dl, test_dl = loading_data()
#device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device1 = torch.device("cuda:0")
device1 = torch.device("cuda")

## CREAR POBLACIÓN ##################################################################################
pop = []
bestAcc = []
bestF = []
bestParams = []
print("Iniciando población...\n")
while len(pop) < N:
  while True:
    try:
      acc_list = []
      #Creating genomes (genetic encoding)
      e1 = Encoding(min_conv,max_conv,min_full,max_full)
      #Decoding the network
      network1 = decoding(e1)
      #Creating the CNN
      cnn1 = CNN(e1, network1[0], network1[1], network1[2])
      print("Individuo {} creado:".format(len(pop)+1))
      #Training the CNN
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc_list)
      #Add individual to population
      pop.append([e1,acc_list[0][1],acc_list[0][2],acc_list[0][3]])
      print("Individuo {} evaluado.\n".format(len(pop)))
      break
    except:
      pass

print("Población creada!!")
# Out:
# Iniciando población...
#
# Individuo 1 creado:
# Individuo 1 evaluado.
#
# Individuo 2 creado:
# Individuo 2 evaluado.
#
# Individuo 3 creado:
# Individuo 3 evaluado.
#
# Individuo 4 creado:
# Individuo 4 evaluado.
#
# Individuo 5 creado:
# Individuo 5 evaluado.
#
# Individuo 6 creado:
# Individuo 6 evaluado.
#
# Individuo 7 creado:
# Individuo 7 evaluado.
#
# Individuo 8 creado:
# Individuo 8 evaluado.
#
# Individuo 9 creado:
# Individuo 9 evaluado.
#
# Individuo 10 creado:
# Individuo 10 evaluado.
#
# Individuo 11 creado:
# Individuo 11 evaluado.
#
# Individuo 12 creado:
# Individuo 12 evaluado.
#
# Individuo 13 creado:
# Individuo 13 evaluado.
#
# Individuo 14 creado:
# Individuo 14 evaluado.
#
# Individuo 15 creado:
# Individuo 15 evaluado.
#
# Individuo 16 creado:
# Individuo 16 evaluado.
#
# Individuo 17 creado:
# Individuo 17 evaluado.
#
# Individuo 18 creado:
# Individuo 18 evaluado.
#
# Individuo 19 creado:
# Individuo 19 evaluado.
#
# Individuo 20 creado:
# Individuo 20 evaluado.
#
# Población creada!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población inicial
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.41810926666666665, acc:0.17123809523809524, param:11716
# f:0.8817238333333334, acc:0.8333333333333334, param:10730
# f:0.848703, acc:0.786, param:9980
# f:0.8083854333333333, acc:0.7273333333333334, param:4986
# f:0.7796038, acc:0.6965714285714286, param:53308
# f:0.8886501333333332, acc:0.8434761904761905, param:11888
# f:0.8474396999999999, acc:0.7898571428571428, param:36402
# f:0.8870458666666665, acc:0.8423809523809523, param:17472
# f:0.8522083333333332, acc:0.7896190476190477, param:3500
# f:0.8173006999999999, acc:0.755, param:74662
# f:0.8945152, acc:0.8572857142857143, param:37232
# f:0.7316753666666667, acc:0.6243809523809524, param:35942
# f:0.8851977, acc:0.897, param:284682
# f:0.8981832999999999, acc:0.8641428571428571, param:44778
# f:0.8916001, acc:0.8474285714285714, param:10666
# f:0.8993805666666667, acc:0.8598095238095238, param:16574
# f:0.7438184333333333, acc:0.6440476190476191, param:46766
# f:0.7874162, acc:0.7018571428571428, param:25892
# f:0.8726145, acc:0.8198571428571428, param:8570
# f:0.7296999666666666, acc:0.6146666666666667, param:3778
# [<EncodingClass.Encoding at 0x7f32a167ef90>,
#  0.8993805666666667,
#  0.8598095238095238,
#  16574]

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.8993805666666667
# Best accuracy:  0.8598095238095238
# Best No. of Params:  16574
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9131749666666666
# Best accuracy:  0.8869523809523809
# Best No. of Params:  51278
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9179934999999999
# Best accuracy:  0.8911428571428571
# Best No. of Params:  38710
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 aleatorio de pop.
# Descendiente 10 evaluado.
# Best fitness:  0.9179934999999999
# Best accuracy:  0.8911428571428571
# Best No. of Params:  38710
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9179934999999999
# Best accuracy:  0.8911428571428571
# Best No. of Params:  38710
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9210935
# Best accuracy:  0.8955714285714286
# Best No. of Params:  38710
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9210935
# Best accuracy:  0.8955714285714286
# Best No. of Params:  38710
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 aleatorio de pop.
# Descendiente 9 evaluado.
# Descendiente 10 aleatorio de pop.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 aleatorio de pop.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  8
# Descendiente 1 aleatorio de pop.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9299924999999999
# Best accuracy:  0.9158571428571428
# Best No. of Params:  74050
# No. of Conv. Layers:  4
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población final
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.9299924999999999, acc:0.9158571428571428, param:74050
# f:0.9299924999999999, acc:0.9158571428571428, param:74050
# f:0.9267148999999999, acc:0.9097142857142857, param:67234
# f:0.9254591666666666, acc:0.9093809523809524, param:74050
# f:0.9251559, acc:0.9, param:32294
# f:0.9244676999999999, acc:0.9098571428571428, param:82882
# f:0.9244012999999999, acc:0.9088571428571428, param:78658
# f:0.9241720333333332, acc:0.9023333333333333, param:49742
# f:0.9237499666666666, acc:0.9135238095238095, param:104778
# f:0.9236482333333332, acc:0.9053333333333333, param:67234
# f:0.9235343666666666, acc:0.9085238095238095, param:82882
# f:0.9233346333333333, acc:0.9073333333333333, param:78658
# f:0.9230439666666665, acc:0.9078095238095238, param:82818
# f:0.9225756999999999, acc:0.9112857142857143, param:102162
# f:0.9225265666666667, acc:0.8963809523809524, param:32934
# f:0.9225225666666665, acc:0.8962380952380953, param:32294
# f:0.9224387000000001, acc:0.8998571428571429, param:49742
# f:0.9219813666666665, acc:0.9000952380952381, param:53902
# f:0.9218258333333333, acc:0.9041904761904762, param:74050
# f:0.9212480333333333, acc:0.8990476190476191, param:53902
# [<EncodingClass.Encoding at 0x7f329e8b3250>,
#  0.9299924999999999,
#  0.9158571428571428,
#  74050]

# %% [markdown]
# # Ejecución 5

# %%
## MÓDULOS ##########################################################################################
from Operators import *
from EncodingClass import *
from Decoding import *
from DataReader import *
from DistributedTraining import *

## LIBRERÍAS ########################################################################################
import numpy as np
from torch import optim
import pandas as pd
import timeit
import torch
from torch import nn
import pickle

## HIPERPARÁMETROS DE LA CNN ########################################################################
loss_func = nn.NLLLoss(reduction = "sum") #Defining loss function
lr = 1e-4 #Defining learning rate
#Maximun and minimum numbers of layers to initialize networks
min_conv = 2
max_conv = 5
min_full = 1
max_full = 4
w = 0.3 #penalization weight
max_params = 2e6
num_epochs = 10

## PARÁMETROS GA ####################################################################################
N = 20 #Population size
cr = 0.7 #Crossover rate
mr = 0.7 #Mutation rate
#T = 50 #Number of generations
t_size = 5 #tournament size
train_dl, test_dl = loading_data()
#device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device1 = torch.device("cuda:0")
device1 = torch.device("cuda")

## CREAR POBLACIÓN ##################################################################################
pop = []
bestAcc = []
bestF = []
bestParams = []
print("Iniciando población...\n")
while len(pop) < N:
  while True:
    try:
      acc_list = []
      #Creating genomes (genetic encoding)
      e1 = Encoding(min_conv,max_conv,min_full,max_full)
      #Decoding the network
      network1 = decoding(e1)
      #Creating the CNN
      cnn1 = CNN(e1, network1[0], network1[1], network1[2])
      print("Individuo {} creado:".format(len(pop)+1))
      #Training the CNN
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc_list)
      #Add individual to population
      pop.append([e1,acc_list[0][1],acc_list[0][2],acc_list[0][3]])
      print("Individuo {} evaluado.\n".format(len(pop)))
      break
    except:
      pass

print("Población creada!!")
# Out:
# Iniciando población...
#
# Individuo 1 creado:
# Individuo 1 evaluado.
#
# Individuo 2 creado:
# Individuo 2 evaluado.
#
# Individuo 3 creado:
# Individuo 3 evaluado.
#
# Individuo 4 creado:
# Individuo 4 evaluado.
#
# Individuo 5 creado:
# Individuo 5 evaluado.
#
# Individuo 6 creado:
# Individuo 6 evaluado.
#
# Individuo 7 creado:
# Individuo 7 evaluado.
#
# Individuo 8 creado:
# Individuo 8 evaluado.
#
# Individuo 9 creado:
# Individuo 9 evaluado.
#
# Individuo 10 creado:
# Individuo 10 evaluado.
#
# Individuo 11 creado:
# Individuo 11 evaluado.
#
# Individuo 12 creado:
# Individuo 12 evaluado.
#
# Individuo 13 creado:
# Individuo 13 evaluado.
#
# Individuo 14 creado:
# Individuo 14 evaluado.
#
# Individuo 15 creado:
# Individuo 15 evaluado.
#
# Individuo 16 creado:
# Individuo 16 evaluado.
#
# Individuo 17 creado:
# Individuo 17 creado:
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Individuo 17 evaluado.
#
# Individuo 18 creado:
# Individuo 18 evaluado.
#
# Individuo 19 creado:
# Individuo 19 evaluado.
#
# Individuo 20 creado:
# Individuo 20 creado:
# Individuo 20 evaluado.
#
# Población creada!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población inicial
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.5957424666666666, acc:0.43852380952380954, param:74828
# f:0.7650638666666667, acc:0.6655238095238095, param:5352
# f:0.9035373, acc:0.9, param:176418
# f:0.7801321333333333, acc:0.6871904761904762, param:6008
# f:0.8751935, acc:0.8814285714285715, param:278710
# f:0.8872509333333332, acc:0.8481904761904762, param:43216
# f:0.7425585333333333, acc:0.6326190476190476, param:1832
# f:0.8967712666666667, acc:0.8595238095238096, param:32636
# f:0.8488969333333333, acc:0.7866190476190477, param:11576
# f:0.8834494666666666, acc:0.8372380952380952, param:17448
# f:0.8690140666666666, acc:0.8162380952380952, param:15684
# f:0.8901205333333333, acc:0.8457619047619047, param:12752
# f:0.8369170333333333, acc:0.7711904761904762, param:19442
# f:0.8155407333333333, acc:0.7500476190476191, param:63284
# f:0.7584979, acc:0.6567142857142857, param:8014
# f:0.8489807999999999, acc:0.7855714285714286, param:6128
# f:0.8305598999999999, acc:0.759, param:4934
# f:0.8131768333333333, acc:0.7360476190476191, param:13710
# f:0.8016597333333333, acc:0.7179047619047619, param:5824
# f:0.8581514333333333, acc:0.7983333333333333, param:4546
# [<EncodingClass.Encoding at 0x7f96efb64990>, 0.9035373, 0.9, 176418]

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 aleatorio de pop.
# Descendiente 7 evaluado.
# Descendiente 8 aleatorio de pop.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9110804333333333
# Best accuracy:  0.8819047619047619
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9110804333333333
# Best accuracy:  0.8819047619047619
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 aleatorio de pop.
# Descendiente 8 evaluado.
# Descendiente 9 aleatorio de pop.
# Descendiente 10 evaluado.
# Best fitness:  0.9110804333333333
# Best accuracy:  0.8819047619047619
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  3
# Descendiente 1 aleatorio de pop.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 aleatorio de pop.
# Best fitness:  0.9110804333333333
# Best accuracy:  0.8819047619047619
# Best No. of Params:  41686
# No. of Conv. Layers:  2
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Fin genético!!

# %%
T = 10 #Number of generations
print("Iniciando genético...")
for t in range(T):
  print('Generation: ', t)
    
  #Parents Selection
  parents = []
  while len(parents) < int(N/2):
    #Tournament Selection
    tournament = random.sample(pop, t_size)
    p1 = selection(tournament, 'max')
    tournament = random.sample(pop, t_size)
    p2 = selection(tournament, 'max')
    while p1 == p2:
      tournament = random.sample(pop, t_size)
      p2 = selection(tournament, 'max')  
        
    parents.append(p1)
    parents.append(p2)
    
    #Reproduction
  offspring = []
  while len(offspring) < int(N/2):
    par = random.sample(parents, 2)
    #Crossover + Mutation
    if cr >= random.uniform(0,1): #Crossover
      p1 = par[0][0]
      p2 = par[1][0]
      c1, c2 = crossover(p1, p2)
            
    #Mutation
    if mr >= random.uniform(0,1):
      mutation(c1)
            
    if mr >= random.uniform(0,1):
      mutation(c2)

    #Try to evaluate the first offspring
    try:
      network1 = decoding(c1)
      cnn1 = CNN(c1, network1[0], network1[1], network1[2])
      acc1_list = []
      training('1', device1, cnn1, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc1_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c1,acc1_list[0][1],acc1_list[0][2],acc1_list[0][3]])
    except:
      c1_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c1_random[0],c1_random[1],c1_random[2],c1_random[3]])

    #Try to evaluate the second offspring
    try:
      network2 = decoding(c2)
      cnn2 = CNN(c2, network2[0], network2[1], network2[2])
      acc2_list = []
      training('2', device1, cnn2, num_epochs, loss_func,train_dl, test_dl, lr, w, max_params, acc2_list)
      print("Descendiente {} evaluado.".format(len(offspring)+1))
      offspring.append([c2,acc2_list[0][1],acc2_list[0][2],acc2_list[0][3]])
    except:
      c2_random = random.sample(pop,1)[0]
      print("Descendiente {} aleatorio de pop.".format(len(offspring)+1))
      offspring.append([c2_random[0],c2_random[1],c2_random[2],c2_random[3]])

  #Replacement with elitism
  pop = pop + offspring
  pop.sort(reverse = True, key = lambda x: x[1])
  pop = pop[:N]
    
  leader = max(pop, key = lambda x: x[1])
  bestAcc.append(leader[2])
  bestF.append(leader[1])
  bestParams.append(leader[3])
    
        
  print('Best fitness: ', leader[1])
  print('Best accuracy: ', leader[2])
  print('Best No. of Params: ', leader[3])
  print('No. of Conv. Layers: ', leader[0].n_conv)
  print('No. of FC Layers: ', leader[0].n_full)
  print('--------------------------------------------')

print("Fin genético!!")
# Out:
# Iniciando genético...
# Generation:  0
# Descendiente 1 aleatorio de pop.
# /usr/local/lib/python3.7/dist-packages/torch/nn/init.py:403: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Descendiente 2 evaluado.
# Descendiente 3 aleatorio de pop.
# Descendiente 4 evaluado.
# Descendiente 5 aleatorio de pop.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  1
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  2
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  3
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9285005
# Best accuracy:  0.9062857142857143
# Best No. of Params:  39330
# No. of Conv. Layers:  3
# No. of FC Layers:  1
# --------------------------------------------
# Generation:  4
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9305986333333334
# Best accuracy:  0.9096190476190477
# Best No. of Params:  40898
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  5
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9305986333333334
# Best accuracy:  0.9096190476190477
# Best No. of Params:  40898
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  6
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9305986333333334
# Best accuracy:  0.9096190476190477
# Best No. of Params:  40898
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  7
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9305986333333334
# Best accuracy:  0.9096190476190477
# Best No. of Params:  40898
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  8
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9305986333333334
# Best accuracy:  0.9096190476190477
# Best No. of Params:  40898
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Generation:  9
# Descendiente 1 evaluado.
# Descendiente 2 evaluado.
# Descendiente 3 evaluado.
# Descendiente 4 evaluado.
# Descendiente 5 evaluado.
# Descendiente 6 evaluado.
# Descendiente 7 evaluado.
# Descendiente 8 evaluado.
# Descendiente 9 evaluado.
# Descendiente 10 evaluado.
# Best fitness:  0.9305986333333334
# Best accuracy:  0.9096190476190477
# Best No. of Params:  40898
# No. of Conv. Layers:  3
# No. of FC Layers:  2
# --------------------------------------------
# Fin genético!!

# %%
#Mostrar aptitudes, precisión y num. parámetros de población final
for network in pop:
  print("f:{}, acc:{}, param:{}".format(network[1],network[2],network[3]))
max(pop, key = lambda x: x[1])
# Out:
# f:0.9305986333333334, acc:0.9096190476190477, param:40898
# f:0.9285005, acc:0.9062857142857143, param:39330
# f:0.9285005, acc:0.9062857142857143, param:39330
# f:0.9280626333333333, acc:0.9064761904761904, param:43138
# f:0.9279986333333333, acc:0.9059047619047619, param:40898
# f:0.9272319666666666, acc:0.9048095238095238, param:40898
# f:0.9268652999999999, acc:0.9042857142857142, param:40898
# f:0.9266319666666666, acc:0.903952380952381, param:40898
# f:0.9264173, acc:0.9045714285714286, param:45218
# f:0.9263319666666666, acc:0.9035238095238095, param:40898
# f:0.9257460999999999, acc:0.9082857142857143, param:67026
# f:0.9255738333333332, acc:0.9034761904761904, param:45730
# f:0.9255218333333333, acc:0.9029047619047619, param:43410
# f:0.9248967666666666, acc:0.9018095238095238, param:42466
# f:0.9246743666666666, acc:0.9025238095238095, param:47282
# f:0.9239918333333332, acc:0.9024761904761904, param:51610
# f:0.9237091666666666, acc:0.8972380952380953, param:29050
# f:0.9237076999999999, acc:0.9011428571428571, param:47282
# f:0.9236997, acc:0.9008571428571429, param:46002
# f:0.9234486333333333, acc:0.9021904761904762, param:53898
# [<EncodingClass.Encoding at 0x7f96efc3af50>,
#  0.9305986333333334,
#  0.9096190476190477,
#  40898]
